# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
hrdata=pd.read_csv('HRDataset.csv')

# %%
hrdata
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
hrdata.size
# Out:
# 11196

# %%
hrdata.shape
# Out:
# (311, 36)

# %%
hrdata.info
# Out:
# <bound method DataFrame.info of                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
hrdata.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
hrdata.tail(5)
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# ...

# %%
hrdata.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
hrdata_=hrdata.loc[:, ['DeptID','ManagerID','ManagerName']]
hrdata_
# Out:
#      DeptID  ManagerID     ManagerName
# 0         5       22.0  Michael Albert
# 1         3        4.0      Simon Roup
# 2         5       20.0  Kissy Sullivan
# 3         5       16.0    Elijiah Gray
# 4         5       39.0  Webster Butler
# ..      ...        ...             ...
# 306       5       20.0  Kissy Sullivan
# 307       5       12.0  Brannon Miller
# 308       3        2.0      Janet King
# 309       3        4.0      Simon Roup
# 310       5       14.0   David Stanley
#
# [311 rows x 3 columns]

# %%
hrdata
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
hrdata['DateofTermination']=hrdata['DateofTermination'].replace(to_replace=np.nan,value=0)
hrdata
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
hrdata.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     8
# RecruitmentSource             0
# ...

# %%
hrdata['ManagerID']=hrdata['ManagerID'].replace(to_replace=np.nan,value=39.0)
hrdata
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
hrdata.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %% [markdown]
# Data Analysis

# %%
#count of employees in each department
Count_Emp=hrdata.groupby('Department')['Department'].count()

# %%
Count_Emp
# Out:
# Department
# Admin Offices             9
# Executive Office          1
# IT/IS                    50
# Production              209
# Sales                    31
# Software Engineering     11
# Name: Department, dtype: int64

# %%
#average salary of employees in each department
Avg_Salary=hrdata.groupby('Department')['Salary'].mean()

# %%
Avg_Salary
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %%
#calculate the average of salary of employees based on gender
sex_salary=hrdata.groupby(['Department','Sex'],as_index=False).Salary.mean()

# %%
sex_salary
# Out:
#               Department Sex         Salary
# 0          Admin Offices   F   70926.333333
# 1          Admin Offices  M    73523.000000
# 2       Executive Office   F  250000.000000
# 3                  IT/IS   F   94593.000000
# 4                  IT/IS  M    99006.642857
# 5      Production          F   59620.420635
# 6      Production         M    60459.253012
# 7                  Sales   F   72016.666667
# 8                  Sales  M    66290.562500
# 9   Software Engineering   F   96906.166667
# 10  Software Engineering  M    92689.400000

# %%
#most popular RecruitmentSource and company based on department
RecruitmentSource=hrdata.groupby(['Department','RecruitmentSource']).size().reset_index(name='counts')

# %%
RecruitmentSource
# Out:
#               Department        RecruitmentSource  counts
# 0          Admin Offices            CareerBuilder       1
# 1          Admin Offices       Diversity Job Fair       3
# 2          Admin Offices                   Indeed       2
# 3          Admin Offices                    Other       1
# 4          Admin Offices                  Website       2
# 5       Executive Office                   Indeed       1
# 6                  IT/IS            CareerBuilder       2
# 7                  IT/IS       Diversity Job Fair       4
# 8                  IT/IS        Employee Referral      13
# 9                  IT/IS            Google Search       1
# 10                 IT/IS                   Indeed      19
# 11                 IT/IS                 LinkedIn      11
# 12     Production                   CareerBuilder      16
# 13     Production              Diversity Job Fair      17
# 14     Production               Employee Referral      16
# ...

# %%
RecruitmentSource.size
# Out:
# 99

# %%
RecruitmentSource.shape
# Out:
# (33, 3)

# %%
#total number of working of days for terminated employees
Employee_Name=input("Enter the Employee Name:")
Employee_Name
# Out:
# Enter the Employee Name:Hari
# 'Hari'

# %%
Start_year=int(input("Enter the start year:"))
Start_month=int(input("Enter the start month:"))
Start_day=int(input("Enter the start day:"))
Start_date=date(Start_year,Start_month,Start_day)
Start_date
# Out:
# Enter the start year:2011
# Enter the start month:5
# Enter the start day:3
# datetime.date(2011, 5, 3)

# %%
T_year=int(input("Enter the Terminated year:"))
T_month=int(input("Enter the Terminated month:"))
T_day=int(input("Enter the Terminated day:"))
T_date=date(T_year,T_month,T_day)
T_date
# Out:
# Enter the Terminated year:2013
# Enter the Terminated month:6
# Enter the Terminated day:6
# datetime.date(2013, 6, 6)

# %%
business_days=pd.bdate_range(Start_date,T_date)
business_days
# Out:
# DatetimeIndex(['2011-05-03', '2011-05-04', '2011-05-05', '2011-05-06',
#                '2011-05-09', '2011-05-10', '2011-05-11', '2011-05-12',
#                '2011-05-13', '2011-05-16',
#                ...
#                '2013-05-24', '2013-05-27', '2013-05-28', '2013-05-29',
#                '2013-05-30', '2013-05-31', '2013-06-03', '2013-06-04',
#                '2013-06-05', '2013-06-06'],
#               dtype='datetime64[ns]', length=548, freq='B')

# %%
print('Employee name:',Employee_Name,'working_days',len(business_days))
# Out:
# Employee name: Hari working_days 548

# %%
#manager name of departments
Manager_Details=hrdata.groupby(['Department','ManagerName','ManagerID']).size().reset_index(name='counts')

# %%
Manager_Details.set_index("ManagerName",inplace=True)
Manager_Details
# Out:
#                               Department  ManagerID  counts
# ManagerName
# Board of Directors         Admin Offices        9.0       1
# Brandon R. LeBlanc         Admin Offices        1.0       6
# Brandon R. LeBlanc         Admin Offices        3.0       1
# Janet King                 Admin Offices        2.0       1
# Board of Directors      Executive Office        9.0       1
# Brian Champaigne                   IT/IS       13.0       8
# Eric Dougall                       IT/IS        6.0       4
# Janet King                         IT/IS        2.0       1
# Jennifer Zamora                    IT/IS        5.0       6
# Peter Monroe                       IT/IS        7.0      14
# Simon Roup                         IT/IS        4.0      17
# Amy Dunn               Production              11.0      21
# Brannon Miller         Production              12.0      22
# David Stanley          Production              14.0      21
# ...

# %%
Manager_Name=input("Enter the manager Name: ")
Dep_value=Manager_Details.loc[[Manager_Name],['Department']]
# Out:
# Enter the manager Name: Lynn Daneault

# %%
Dep_value
# Out:
#               Department
# ManagerName
# Lynn Daneault      Sales

# %%
#Fetch Employee name and number of absences.
Emp_Attendance=hrdata.loc[:,['Department','ManagerName','Employee_Name','Absences']]
Emp_Attendance
# Out:
#             Department     ManagerName             Employee_Name  Absences
# 0    Production         Michael Albert       Adinolfi, Wilson  K         1
# 1                IT/IS      Simon Roup  Ait Sidi, Karthikeyan           17
# 2    Production         Kissy Sullivan         Akinkuolie, Sarah         3
# 3    Production           Elijiah Gray              Alagbe,Trina        15
# 4    Production         Webster Butler          Anderson, Carol          2
# ..                 ...             ...                       ...       ...
# 306  Production         Kissy Sullivan            Woodson, Jason        13
# 307  Production         Brannon Miller        Ybarra, Catherine          4
# 308              IT/IS      Janet King          Zamora, Jennifer        16
# 309              IT/IS      Simon Roup               Zhou, Julia        11
# 310  Production          David Stanley             Zima, Colleen         2
#
# [311 rows x 4 columns]

# %%
#END OF DATA ANALYSIS
